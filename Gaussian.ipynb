# %% [markdown]
# ## Gaussian
# ## Alaa Elsayed Mohamed Desukey

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
from plotnine import *

from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

from sklearn.cluster import DBSCAN
from sklearn.cluster import AgglomerativeClustering


from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture

from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from sklearn import metrics


# %matplotlib inline

# %% [markdown]
# # Gaussian with Multiple Data Sets
#
# ## Dataset1

# %%
d1 = pd.read_csv("https://raw.githubusercontent.com/cmparlettpelleriti/CPSC392ParlettPelleriti/master/Data/KMEM1.csv")

d1.head()
# Out:
#           x         y
# 0  1.206087  1.847686
# 1  0.351919  0.245691
# 2  1.201688  0.630774
# 3  0.733710  1.364328
# 4  1.150745  0.724892

# %%
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(d1)
    distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(16,8))
plt.plot(K, distortions, marker = 'o')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
hac = AgglomerativeClustering(3)
km = KMeans(3)
gm = GaussianMixture(3)
db = DBSCAN(eps=0.3, min_samples=10)

hac.fit(d1)
km.fit(d1)
gm.fit(d1)
db.fit(d1)

d1["hac"] = hac.labels_
d1["km"]  = km.labels_
d1["gm"]  = gm.predict(d1[["x","y"]])
d1["db"]  = db.labels_

# %%
print(ggplot(d1, aes(x = "x", y = "y",
                    color = "factor(hac)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "Hierarchical Agglomeretive"))


print(ggplot(d1, aes(x = "x", y = "y",
                    color = "factor(km)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "KMeans"))


print(ggplot(d1, aes(x = "x", y = "y",
                    color = "factor(gm)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "Gaussian Mixtures"))
print(ggplot(d1, aes(x = "x", y = "y",
                    color = "factor(db)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "DBSCAN"))

# %%
print("Silhouette Coefficient(Hierarchical Agglomeretive): %0.3f" % metrics.silhouette_score(d1, d1["hac"]))
print("Silhouette Coefficient(KMeans): %0.3f" % metrics.silhouette_score(d1, d1["km"]))
print("Silhouette Coefficient(Gaussian Mixtures): %0.3f" % metrics.silhouette_score(d1, d1["gm"]))
print("Silhouette Coefficient(DBSCAN): %0.3f" % metrics.silhouette_score(d1, d1["db"]))
# Out:
# Silhouette Coefficient(Hierarchical Agglomeretive): 0.477
# Silhouette Coefficient(KMeans): 0.467
# Silhouette Coefficient(Gaussian Mixtures): 0.443
# Silhouette Coefficient(DBSCAN): 0.327

# %% [markdown]
# ## Dataset 2

# %%
d2 = pd.read_csv("https://raw.githubusercontent.com/cmparlettpelleriti/CPSC392ParlettPelleriti/master/Data/KMEM2.csv")

d2.head()
# Out:
#           x         y
# 0  1.578527  1.408111
# 1  1.748206  0.441915
# 2  1.523151  0.681521
# 3  1.318949  0.362971
# 4  0.977164 -0.373589

# %%
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(d2)
    distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(16,8))
plt.plot(K, distortions, marker = 'o')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
hac = AgglomerativeClustering(3)
km = KMeans(3)
gm = GaussianMixture(3)
db = DBSCAN(eps=0.3, min_samples=10)

hac.fit(d2)
km.fit(d2)
gm.fit(d2)
db.fit(d2)

d2["hac"] = hac.labels_
d2["km"]  = km.labels_
d2["gm"]  = gm.predict(d2[["x","y"]])
d2["db"]  = db.labels_

# %%
print(ggplot(d2, aes(x = "x", y = "y",
                    color = "factor(hac)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "Hierarchical Agglomeretive"))


print(ggplot(d2, aes(x = "x", y = "y",
                    color = "factor(km)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "KMeans"))


print(ggplot(d2, aes(x = "x", y = "y",
                    color = "factor(gm)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "Gaussian Mixtures"))
print(ggplot(d2, aes(x = "x", y = "y",
                    color = "factor(db)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "DBSCAN"))

# %%
print("Silhouette Coefficient(Hierarchical Agglomeretive): %0.3f" % metrics.silhouette_score(d2, d2["hac"]))
print("Silhouette Coefficient(KMeans): %0.3f" % metrics.silhouette_score(d2, d2["km"]))
print("Silhouette Coefficient(Gaussian Mixtures): %0.3f" % metrics.silhouette_score(d2, d2["gm"]))
print("Silhouette Coefficient(DBSCAN): %0.3f" % metrics.silhouette_score(d2, d2["db"]))
# Out:
# Silhouette Coefficient(Hierarchical Agglomeretive): 0.586
# Silhouette Coefficient(KMeans): 0.598
# Silhouette Coefficient(Gaussian Mixtures): 0.598
# Silhouette Coefficient(DBSCAN): 0.489

# %% [markdown]
# ## Dataset 3

# %%
d3 = pd.read_csv("https://raw.githubusercontent.com/cmparlettpelleriti/CPSC392ParlettPelleriti/master/Data/KMEM3.csv")

d3.head()
# Out:
#           x         y
# 0  1.332228  0.178299
# 1  1.256056  0.146765
# 2  1.477661  0.155054
# 3  1.384840  0.022054
# 4  1.526956  0.267920

# %%
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(d3)
    distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(16,8))
plt.plot(K, distortions, marker = 'o')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
hac = AgglomerativeClustering(3)
km = KMeans(3)
gm = GaussianMixture(3)
db = DBSCAN(eps=0.3, min_samples=10)

hac.fit(d3)
km.fit(d3)
gm.fit(d3)
db.fit(d3)

d3["hac"] = hac.labels_
d3["km"]  = km.labels_
d3["gm"]  = gm.predict(d3[["x","y"]])
d3["db"]  = db.labels_

# %%
print(ggplot(d3, aes(x = "x", y = "y",
                    color = "factor(hac)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "Hierarchical Agglomeretive"))


print(ggplot(d3, aes(x = "x", y = "y",
                    color = "factor(km)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "KMeans"))


print(ggplot(d3, aes(x = "x", y = "y",
                    color = "factor(gm)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "Gaussian Mixtures"))
print(ggplot(d3, aes(x = "x", y = "y",
                    color = "factor(db)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "DBSCAN"))

# %%
print("Silhouette Coefficient(Hierarchical Agglomeretive): %0.3f" % metrics.silhouette_score(d3, d3["hac"]))
print("Silhouette Coefficient(KMeans): %0.3f" % metrics.silhouette_score(d3, d3["km"]))
print("Silhouette Coefficient(Gaussian Mixtures): %0.3f" % metrics.silhouette_score(d3, d3["gm"]))
print("Silhouette Coefficient(DBSCAN): %0.3f" % metrics.silhouette_score(d3, d3["db"]))
# Out:
# Silhouette Coefficient(Hierarchical Agglomeretive): 0.936
# Silhouette Coefficient(KMeans): 0.936
# Silhouette Coefficient(Gaussian Mixtures): 0.936
# Silhouette Coefficient(DBSCAN): 0.936

# %% [markdown]
# ## Dataset 4

# %%
d4 = pd.read_csv("https://raw.githubusercontent.com/cmparlettpelleriti/CPSC392ParlettPelleriti/master/Data/KMEM4.csv")

d4.head()
# Out:
#           x         y
# 0 -0.006848  0.395527
# 1  0.314820 -0.289261
# 2  0.171705  1.078077
# 3 -1.203661  1.325926
# 4 -0.179379 -0.036615

# %%
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(d4)
    distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(16,8))
plt.plot(K, distortions, marker = 'o')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
hac = AgglomerativeClustering(3)
km = KMeans(3)
gm = GaussianMixture(3)
db = DBSCAN(eps=0.5, min_samples=10)

hac.fit(d4)
km.fit(d4)
gm.fit(d4)
db.fit(d4)

d4["hac"] = hac.labels_
d4["km"]  = km.labels_
d4["gm"]  = gm.predict(d4[["x","y"]])
d4["db"]  = db.labels_

# %%
print(ggplot(d4, aes(x = "x", y = "y",
                    color = "factor(hac)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "Hierarchical Agglomeretive"))


print(ggplot(d4, aes(x = "x", y = "y",
                    color = "factor(km)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "KMeans"))


print(ggplot(d4, aes(x = "x", y = "y",
                    color = "factor(gm)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "Gaussian Mixtures"))
print(ggplot(d4, aes(x = "x", y = "y",
                    color = "factor(db)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "DBSCAN"))

# %%
print("Silhouette Coefficient(Hierarchical Agglomeretive): %0.3f" % metrics.silhouette_score(d4, d4["hac"]))
print("Silhouette Coefficient(KMeans): %0.3f" % metrics.silhouette_score(d4, d4["km"]))
print("Silhouette Coefficient(Gaussian Mixtures): %0.3f" % metrics.silhouette_score(d4, d4["gm"]))
print("Silhouette Coefficient(DBSCAN): %0.3f" % metrics.silhouette_score(d4, d4["db"]))
# Out:
# Silhouette Coefficient(Hierarchical Agglomeretive): 0.333
# Silhouette Coefficient(KMeans): 0.375
# Silhouette Coefficient(Gaussian Mixtures): 0.319
# Silhouette Coefficient(DBSCAN): 0.519

# %% [markdown]
# ## Dataset 5

# %%
d5 = pd.read_csv("https://raw.githubusercontent.com/cmparlettpelleriti/CPSC392ParlettPelleriti/master/Data/KMEM5.csv")

d5.head()
# Out:
#           x         y
# 0  2.852449 -0.324568
# 1  2.346342 -0.729224
# 2  2.229033 -0.599340
# 3  2.458669 -0.385467
# 4  2.844177 -0.196813

# %%
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(d5)
    distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(16,8))
plt.plot(K, distortions, marker = 'o')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
hac = AgglomerativeClustering(3)
km = KMeans(3)
gm = GaussianMixture(3)
db = DBSCAN(eps=0.5, min_samples=15)

hac.fit(d5)
km.fit(d5)
gm.fit(d5)
db.fit(d5)

d5["hac"] = hac.labels_
d5["km"]  = km.labels_
d5["gm"]  = gm.predict(d5[["x","y"]])
d5["db"]  = db.labels_

# %%
print(ggplot(d5, aes(x = "x", y = "y",
                    color = "factor(hac)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "Hierarchical Agglomeretive"))


print(ggplot(d5, aes(x = "x", y = "y",
                    color = "factor(km)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "KMeans"))


print(ggplot(d5, aes(x = "x", y = "y",
                    color = "factor(gm)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "Gaussian Mixtures"))
print(ggplot(d5, aes(x = "x", y = "y",
                    color = "factor(db)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "DBSCAN"))

# %%
print("Silhouette Coefficient(Hierarchical Agglomeretive): %0.3f" % metrics.silhouette_score(d5, d5["hac"]))
print("Silhouette Coefficient(KMeans): %0.3f" % metrics.silhouette_score(d5, d5["km"]))
print("Silhouette Coefficient(Gaussian Mixtures): %0.3f" % metrics.silhouette_score(d5, d5["gm"]))
print("Silhouette Coefficient(DBSCAN): %0.3f" % metrics.silhouette_score(d5, d5["db"]))
# Out:
# Silhouette Coefficient(Hierarchical Agglomeretive): 0.777
# Silhouette Coefficient(KMeans): 0.779
# Silhouette Coefficient(Gaussian Mixtures): 0.779
# Silhouette Coefficient(DBSCAN): 0.757

# %% [markdown]
# ## Dataset 6

# %%
d6 = pd.read_csv("https://raw.githubusercontent.com/cmparlettpelleriti/CPSC392ParlettPelleriti/master/Data/KMEM6.csv")

d6.head()
# Out:
#           x         y
# 0  0.712520  0.653491
# 1  0.910914  0.068242
# 2  0.750752  0.526512
# 3  0.666605  0.584747
# 4  0.403062  0.956459

# %%
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(d6)
    distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(16,8))
plt.plot(K, distortions, marker = 'o')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
# we ask for 4 nearest, because the data point it self (distance = 0) is included
hac = AgglomerativeClustering(3)
km = KMeans(3)
gm = GaussianMixture(3)
db = DBSCAN(eps=0.5, min_samples=10)

hac.fit(d6)
km.fit(d6)
gm.fit(d6)
db.fit(d6)

d6["hac"] = hac.labels_
d6["km"]  = km.labels_
d6["gm"]  = gm.predict(d6[["x","y"]])
d6["db"]  = db.labels_

# %%
print(ggplot(d6, aes(x = "x", y = "y",
                    color = "factor(hac)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "Hierarchical Agglomeretive"))


print(ggplot(d6, aes(x = "x", y = "y",
                    color = "factor(km)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "KMeans"))


print(ggplot(d6, aes(x = "x", y = "y",
                    color = "factor(gm)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "Gaussian Mixtures"))
print(ggplot(d6, aes(x = "x", y = "y",
                    color = "factor(db)")) +
             geom_point() +
             theme_minimal() +
             scale_color_discrete(name = "Cluster Assignment") +
             theme(panel_grid_major = element_blank()) + 
             labs(title = "DBSCAN"))

# %%
print("Silhouette Coefficient(Hierarchical Agglomeretive): %0.3f" % metrics.silhouette_score(d6, d6["hac"]))
print("Silhouette Coefficient(KMeans): %0.3f" % metrics.silhouette_score(d6, d6["km"]))
print("Silhouette Coefficient(Gaussian Mixtures): %0.3f" % metrics.silhouette_score(d6, d6["gm"]))
print("Silhouette Coefficient(DBSCAN): %0.3f" % metrics.silhouette_score(d6, d6["db"]))
# Out:
# Silhouette Coefficient(Hierarchical Agglomeretive): 0.598
# Silhouette Coefficient(KMeans): 0.648
# Silhouette Coefficient(Gaussian Mixtures): 0.641
# Silhouette Coefficient(DBSCAN): 0.397
